# %% [markdown]
# # <font color="#ff2655" size=24px>ICT - DSA - Exit Test - P J Athul </font>

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dftest = pd.read_csv("test.csv")
dftrain = pd.read_csv("train.csv")

dftest.head()
# Out:
#     CustomerID   Age  Gender          City is_Married  family_size  height  \
# 0  CusID_30000  32.0  Female         Delhi    Married          6.0   142.0
# 1  CusID_30001  22.0    Male         Perth   Divorced          4.0   155.0
# 2  CusID_30002  46.0  Female     Barcelona    Married          2.0     NaN
# 3  CusID_30003  35.0     NaN  Kuala Lampur     Single          1.0   137.0
# 4  CusID_30004  48.0    Male        Sydney    Married          3.0   162.0
#
#    annual_income       job is_physically_ok has_taken_car_loan  \
# 0       150800.0   Service              Yes                 No
# 1       167000.0   Service              Yes                 No
# 2        66000.0   Service              Yes                 No
# 3        71820.0  Business              Yes                NaN
# 4         6500.0   Service              Yes                Yes
#
#   preferable_fuel_choice
# 0                 Diesel
# 1                 Petrol
# 2                 Petrol
# 3                 Petrol
# ...

# %%
dftrain.head()
# Out:
#     CustomerID   Age         Gender           City is_Married  family_size  \
# 0  CusID_00000  36.0           Male  New York City   Divorced          2.0
# 1  CusID_00001  15.0         Female  New York City     Single          1.0
# 2  CusID_00002  55.0           Male          Paris    Married          2.0
# 3  CusID_00003  23.0           Male      Vancouver   Divorced          3.0
# 4  CusID_00004  23.0  Not_Specified      Vancouver     Single          1.0
#
#    height  annual_income       job is_physically_ok has_taken_car_loan  \
# 0   160.0        32200.0   Service              Yes                Yes
# 1   143.0         9000.0   Service              Yes                Yes
# 2   168.0       152400.0   Service              Yes                 No
# 3   165.0       141140.0  Business              Yes                 No
# 4   147.0        38100.0   Service              Yes                Yes
#
#   preferable_fuel_choice           vehicle_choice
# ...

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="Gender",data = dftrain)
plt.show()

# %%
plt.figure(figsize=(25,5))
sns.countplot(x="City",data = dftrain)
plt.show()

# %%
plt.figure(figsize=(25,5))
sns.countplot(x="is_Married",data = dftrain)
plt.show()

# %%
plt.figure(figsize=(25,5))
sns.countplot(x="family_size",data = dftrain)
plt.show()

# %%
plt.figure(figsize=(25,5))
sns.countplot(x="job",data = dftrain)
plt.show()

# %%
plt.figure(figsize=(25,5))
sns.countplot(x="is_physically_ok",data = dftrain)
plt.show()

# %%
plt.figure(figsize=(25,5))
sns.countplot(x="has_taken_car_loan",data = dftrain)
plt.show()

# %%
plt.figure(figsize=(25,5))
sns.countplot(x="preferable_fuel_choice",data = dftrain)
plt.show()

# %%
plt.figure(figsize=(25,5))
sns.countplot(x="vehicle_choice",data = dftrain)
plt.show()

# %%
sns.pairplot(dftrain)

# %%
dftrain.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'City', 'is_Married', 'family_size',
#        'height', 'annual_income', 'job', 'is_physically_ok',
#        'has_taken_car_loan', 'preferable_fuel_choice', 'vehicle_choice'],
#       dtype='object')

# %%
dftrain.Gender.nunique()
# Out:
# 7

# %%
dftrain.Gender.unique()
# Out:
# array(['Male', 'Female', 'Not_Specified', nan, 'ZH#C@', 'VG?H%', 'SA#?I',
#        'TD%Q@'], dtype=object)

# %%
dftrain.Gender.replace(to_replace =['ZH#C@', 'VG?H%', 'SA#?I',
       'TD%Q@'], 
                            value ="Not_Specified",inplace=True)

# %%
dftest.Gender.unique()
# Out:
# array(['Female', 'Male', nan, 'Not_Specified', 'EV%N?', 'N%E#G'],
#       dtype=object)

# %%
dftest.Gender.replace(to_replace =['EV%N?', 'N%E#G'], 
                            value ="Not_Specified",inplace=True)

# %%
dftrain.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'City', 'is_Married', 'family_size',
#        'height', 'annual_income', 'job', 'is_physically_ok',
#        'has_taken_car_loan', 'preferable_fuel_choice', 'vehicle_choice'],
#       dtype='object')

# %%
dftrain.City.unique()
# Out:
# array(['New York City', 'Paris', 'Vancouver', 'Barcelona', 'Los Angeles',
#        'Toronto', 'Munich', 'Chennai', 'Florence', 'Budapest', 'Kolkata',
#        'San Francisco', 'London', 'Mumbai', 'Taipei', 'Kuala Lampur',
#        'Shinjuku', 'Perth', 'Sydney', 'Berlin', 'Vienna', 'Delhi', nan,
#        '#VPI@', '#B?TL', '#XY@G', 'P?IX@'], dtype=object)

# %%
dftrain.Gender.replace(to_replace =['#VPI@', '#B?TL', '#XY@G', 'P?IX@'], 
                            value ="Not_Specified",inplace=True)

# %%
dftest.City.unique()
# Out:
# array(['Delhi', 'Perth', 'Barcelona', 'Kuala Lampur', 'Sydney',
#        'Vancouver', 'New York City', 'Kolkata', 'Florence', 'Mumbai',
#        'Chennai', 'Toronto', 'Budapest', 'Taipei', 'Vienna',
#        'San Francisco', 'Los Angeles', 'Shinjuku', 'London', 'Berlin',
#        'Paris', 'Munich', nan, '%?ACE'], dtype=object)

# %%
dftest.Gender.replace(to_replace =['%?ACE'], 
                            value ="nan",inplace=True)

# %%
dftrain.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'City', 'is_Married', 'family_size',
#        'height', 'annual_income', 'job', 'is_physically_ok',
#        'has_taken_car_loan', 'preferable_fuel_choice', 'vehicle_choice'],
#       dtype='object')

# %%
dftrain.is_Married.unique()
# Out:
# array(['Divorced', 'Single', 'Married', nan, 'T@JF%', 'ORV@#', '?D@NF',
#        'S#TF%', '@XTZ?'], dtype=object)

# %%
dftest.is_Married.unique()
# Out:
# array(['Married', 'Divorced', 'Single', nan], dtype=object)

# %%
dftrain.is_Married.replace(to_replace =['T@JF%', 'ORV@#', '?D@NF',
       'S#TF%', '@XTZ?'], 
                            value ="Not_Specified",inplace=True)

# %%
print(dftrain.job.unique())
print(dftest.job.unique())
# Out:
# ['Service' 'Business' 'Student' nan 'Undisclosed' 'KBN?#' 'UZT?@' 'Z@B%L'
#  'TV%?N']
# ['Service' 'Business' 'Undisclosed' 'Student' nan]

# %%
dftrain.is_Married.replace(to_replace =['KBN?#', 'UZT?@' ,'Z@B%L'
 'TV%?N'], 
                            value ="nan",inplace=True)

# %%
print(dftrain.is_physically_ok.unique())
print(dftest.is_physically_ok.unique())
# Out:
# ['Yes' 'No' nan 'Y%?UH' 'UY%X@']
# ['Yes' 'No' nan 'K%#MY']

# %%
dftrain.is_physically_ok.replace(to_replace =['Y%?UH' ,'UY%X@'], 
                            value ="Unknown",inplace=True)
dftest.is_physically_ok.replace(to_replace =['K%#MY'], 
                            value ="Unknown",inplace=True)

# %%
print(dftest.is_physically_ok.unique())
# Out:
# ['Yes' 'No' nan 'Unknown']

# %%
print(dftrain.has_taken_car_loan.unique())
print(dftest.has_taken_car_loan.unique())
# Out:
# ['Yes' 'No' nan '@W%GO' '?N%IY' 'AF?V%']
# ['No' nan 'Yes' 'U#@DX' 'DG?#H']

# %%
dftrain.has_taken_car_loan.replace(to_replace =['@W%GO' ,'?N%IY', 'AF?V%'], 
                            value ="Unknown",inplace=True)
dftest.has_taken_car_loan.replace(to_replace =['U#@DX' ,'DG?#H'], 
                            value ="Unknown",inplace=True)

# %%
print(dftrain.has_taken_car_loan.unique())
print(dftest.has_taken_car_loan.unique())
# Out:
# ['Yes' 'No' nan 'Unknown']
# ['No' nan 'Yes' 'Unknown']

# %%
print(dftrain.preferable_fuel_choice.unique())
print(dftest.preferable_fuel_choice.unique())
# Out:
# ['Hybrid' 'Petrol' 'Diesel' 'EV' nan 'SVY@#' 'IX%K#' '#%KXJ']
# ['Diesel' 'Petrol' 'Hybrid' 'EV' nan 'FC?P%']

# %%
dftrain.preferable_fuel_choice.replace(to_replace =['SVY@#', 'IX%K#' ,'#%KXJ'], 
                            value ="Unknown",inplace=True)
dftest.preferable_fuel_choice.replace(to_replace =['FC?P%'], 
                            value ="Unknown",inplace=True)

# %%
print(dftrain.preferable_fuel_choice.unique())
print(dftest.preferable_fuel_choice.unique())
# Out:
# ['Hybrid' 'Petrol' 'Diesel' 'EV' nan 'Unknown']
# ['Diesel' 'Petrol' 'Hybrid' 'EV' nan 'Unknown']

# %% [markdown]
# # <font color="#fc6f03" >Handling Missing Values </font>

# %%
dftrain.isna().sum()
# Out:
# CustomerID                  0
# Age                       439
# Gender                    417
# City                      423
# is_Married                420
# family_size               414
# height                    431
# annual_income             419
# job                       428
# is_physically_ok          422
# has_taken_car_loan        431
# preferable_fuel_choice    428
# vehicle_choice              0
# dtype: int64

# %%
dftrain.describe()
# Out:
#                 Age   family_size        height  annual_income
# count  29561.000000  29586.000000  29569.000000   29581.000000
# mean      30.998545      2.876225    153.023741   84678.162672
# std        9.904351      1.633711     11.175516   60802.123202
# min       15.000000      1.000000    130.000000    2000.000000
# 25%       24.000000      1.000000    144.000000   36820.000000
# 50%       30.000000      3.000000    152.000000   82070.000000
# 75%       36.000000      4.000000    160.000000  128210.000000
# max       60.000000      6.000000    180.000000  499000.000000

# %%
dftest.isna().sum()
# Out:
# CustomerID                 0
# Age                       67
# Gender                    81
# City                      72
# is_Married                85
# family_size               73
# height                    67
# annual_income             78
# job                       74
# is_physically_ok          66
# has_taken_car_loan        61
# preferable_fuel_choice    83
# dtype: int64

# %%
#Handling missing values in train dataset
col_numeric = dftrain.select_dtypes(include=(['int64', 'float64'])).columns
for col in col_numeric:
    dftrain[col].fillna(dftrain[col].median(), inplace=True)

col_obj = dftrain.select_dtypes(include=(['object'])).columns
for col in col_obj:
    dftrain[col].fillna(dftrain[col].mode().values[0], inplace=True)

dftrain.isna().sum()
# Out:
# CustomerID                0
# Age                       0
# Gender                    0
# City                      0
# is_Married                0
# family_size               0
# height                    0
# annual_income             0
# job                       0
# is_physically_ok          0
# has_taken_car_loan        0
# preferable_fuel_choice    0
# vehicle_choice            0
# dtype: int64

# %%
#Handling missing values in test dataset
col_numeric = dftest.select_dtypes(include=(['int64', 'float64'])).columns
for col in col_numeric:
    dftest[col].fillna(dftest[col].median(), inplace=True)

col_obj = dftest.select_dtypes(include=(['object'])).columns
for col in col_obj:
    dftest[col].fillna(dftest[col].mode().values[0], inplace=True)

dftest.isna().sum()
# Out:
# CustomerID                0
# Age                       0
# Gender                    0
# City                      0
# is_Married                0
# family_size               0
# height                    0
# annual_income             0
# job                       0
# is_physically_ok          0
# has_taken_car_loan        0
# preferable_fuel_choice    0
# dtype: int64

# %% [markdown]
# # <font color="#42b36d" >Encoding</font>

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# Encoding Train Dataset
obj_feat = dftrain.dtypes[dftrain.dtypes == 'O'].index.values
le = LabelEncoder()
obj_feat = list(obj_feat)
obj_feat
# Out:
# ['CustomerID',
#  'Gender',
#  'City',
#  'is_Married',
#  'job',
#  'is_physically_ok',
#  'has_taken_car_loan',
#  'preferable_fuel_choice',
#  'vehicle_choice']

# %%
obj_feat.pop()
print(obj_feat)
obj_feat = ['Gender', 'City', 'is_Married', 'job', 'is_physically_ok', 'has_taken_car_loan', 'preferable_fuel_choice']
# Out:
# ['CustomerID', 'Gender', 'City', 'is_Married', 'job', 'is_physically_ok', 'has_taken_car_loan', 'preferable_fuel_choice']

# %%
for i in obj_feat:
    dftrain[i] = le.fit_transform(dftrain[i])

# %%
dftrain.head()
# Out:
#     CustomerID   Age  Gender  City  is_Married  family_size  height  \
# 0  CusID_00000  36.0       1    15           0          2.0   160.0
# 1  CusID_00001  15.0       0    15           3          1.0   143.0
# 2  CusID_00002  55.0       1    17           1          2.0   168.0
# 3  CusID_00003  23.0       1    24           0          3.0   165.0
# 4  CusID_00004  23.0       2    24           3          1.0   147.0
#
#    annual_income  job  is_physically_ok  has_taken_car_loan  \
# 0        32200.0    2                 2                   2
# 1         9000.0    2                 2                   2
# 2       152400.0    2                 2                   0
# 3       141140.0    0                 2                   0
# 4        38100.0    2                 2                   2
#
#    preferable_fuel_choice           vehicle_choice
# 0                       2                    Sedan
# 1                       3  Compact Utility Vehicle
# ...

# %%
obj_feat = dftest.dtypes[dftest.dtypes == 'O'].index.value
obj_feat
# Out:
# array(['CustomerID', 'Gender', 'City', 'is_Married', 'job',
#        'is_physically_ok', 'has_taken_car_loan', 'preferable_fuel_choice'],
#       dtype=object)

# %%
obj_feat = ['Gender', 'City', 'is_Married', 'job',
       'is_physically_ok', 'has_taken_car_loan', 'preferable_fuel_choice']

# %%
# Encoding Test Dataset

le = LabelEncoder()
for i in obj_feat:
    dftest[i] = le.fit_transform(dftest[i])

# %%
dftest.head()
# Out:
#     CustomerID   Age  Gender  City  is_Married  family_size  height  \
# 0  CusID_30000  32.0       0     5           1          6.0   142.0
# 1  CusID_30001  22.0       1    15           0          4.0   155.0
# 2  CusID_30002  46.0       0     1           1          2.0   152.0
# 3  CusID_30003  35.0       0     8           2          1.0   137.0
# 4  CusID_30004  48.0       1    18           1          3.0   162.0
#
#    annual_income  job  is_physically_ok  has_taken_car_loan  \
# 0       150800.0    1                 2                   0
# 1       167000.0    1                 2                   0
# 2        66000.0    1                 2                   0
# 3        71820.0    0                 2                   0
# 4         6500.0    1                 2                   2
#
#    preferable_fuel_choice
# 0                       0
# 1                       3
# 2                       3
# 3                       3
# 4                       2

# %%
dftrain.head()
# Out:
#     CustomerID   Age  Gender  City  is_Married  family_size  height  \
# 0  CusID_00000  36.0       1    15           0          2.0   160.0
# 1  CusID_00001  15.0       0    15           3          1.0   143.0
# 2  CusID_00002  55.0       1    17           1          2.0   168.0
# 3  CusID_00003  23.0       1    24           0          3.0   165.0
# 4  CusID_00004  23.0       2    24           3          1.0   147.0
#
#    annual_income  job  is_physically_ok  has_taken_car_loan  \
# 0        32200.0    2                 2                   2
# 1         9000.0    2                 2                   2
# 2       152400.0    2                 2                   0
# 3       141140.0    0                 2                   0
# 4        38100.0    2                 2                   2
#
#    preferable_fuel_choice           vehicle_choice
# 0                       2                    Sedan
# 1                       3  Compact Utility Vehicle
# ...

# %% [markdown]
# # <font color="#351963" >Handling Outlier & Skewness</font>

# %%
dftrain.plot(kind = 'box', subplots = True, layout = (3,9),sharex = False, sharey = False, 
        figsize = (20,30), color ="#ff2655")
# Out:
# Age                          AxesSubplot(0.125,0.657941;0.0731132x0.222059)
# Gender                    AxesSubplot(0.212736,0.657941;0.0731132x0.222059)
# City                      AxesSubplot(0.300472,0.657941;0.0731132x0.222059)
# is_Married                AxesSubplot(0.388208,0.657941;0.0731132x0.222059)
# family_size               AxesSubplot(0.475943,0.657941;0.0731132x0.222059)
# height                    AxesSubplot(0.563679,0.657941;0.0731132x0.222059)
# annual_income             AxesSubplot(0.651415,0.657941;0.0731132x0.222059)
# job                       AxesSubplot(0.739151,0.657941;0.0731132x0.222059)
# is_physically_ok          AxesSubplot(0.826887,0.657941;0.0731132x0.222059)
# has_taken_car_loan           AxesSubplot(0.125,0.391471;0.0731132x0.222059)
# preferable_fuel_choice    AxesSubplot(0.212736,0.391471;0.0731132x0.222059)
# dtype: object

# %%
dftest.plot(kind = 'box', subplots = True, layout = (3,9),sharex = False, sharey = False, 
        figsize = (20,30), color ="#ff2655")
# Out:
# Age                          AxesSubplot(0.125,0.657941;0.0731132x0.222059)
# Gender                    AxesSubplot(0.212736,0.657941;0.0731132x0.222059)
# City                      AxesSubplot(0.300472,0.657941;0.0731132x0.222059)
# is_Married                AxesSubplot(0.388208,0.657941;0.0731132x0.222059)
# family_size               AxesSubplot(0.475943,0.657941;0.0731132x0.222059)
# height                    AxesSubplot(0.563679,0.657941;0.0731132x0.222059)
# annual_income             AxesSubplot(0.651415,0.657941;0.0731132x0.222059)
# job                       AxesSubplot(0.739151,0.657941;0.0731132x0.222059)
# is_physically_ok          AxesSubplot(0.826887,0.657941;0.0731132x0.222059)
# has_taken_car_loan           AxesSubplot(0.125,0.391471;0.0731132x0.222059)
# preferable_fuel_choice    AxesSubplot(0.212736,0.391471;0.0731132x0.222059)
# dtype: object

# %%
cols = ['Age','annual_income']
dftrain[cols].hist(figsize=(20,20))
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'annual_income'}>]], dtype=object)

# %%
dftest[cols].hist(figsize=(20,20))
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'annual_income'}>]], dtype=object)

# %%
#Log transformation to remove skewness
for col in cols:
    dftrain[col] = dftrain[col].apply(lambda x: np.log(x + 1))
    dftest[col] = dftest[col].apply(lambda x: np.log(x + 1))

# %%
dftrain[cols].hist(figsize=(10,5))
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'annual_income'}>]], dtype=object)

# %%
dftest[cols].hist(figsize=(10,5))
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'annual_income'}>]], dtype=object)

# %%
#Handling Outlier - Train
Q1 = dftrain[cols].quantile(0.25)
Q3 = dftrain[cols].quantile(0.75)
IQR = Q3 - Q1
whisker_width = 1.5
lower_whisker = Q1 -(whisker_width*IQR)
upper_whisker = Q3 + (whisker_width*IQR)
dftrain[cols]=np.where(dftrain[cols]>upper_whisker,upper_whisker,np.where(dftrain[cols]<lower_whisker,lower_whisker,dftrain[cols]))

# %%
#Handling Outlier - Test
Q1 = dftest[cols].quantile(0.25)
Q3 = dftest[cols].quantile(0.75)
IQR = Q3 - Q1
whisker_width = 1.5
lower_whisker = Q1 -(whisker_width*IQR)
upper_whisker = Q3 + (whisker_width*IQR)
dftest[cols]=np.where(dftest[cols]>upper_whisker,upper_whisker,np.where(dftest[cols]<lower_whisker,lower_whisker,dftest[cols]))

# %%
dftrain.head()
# Out:
#     CustomerID       Age  Gender  City  is_Married  family_size  height  \
# 0  CusID_00000  3.610918       1    15           0          2.0   160.0
# 1  CusID_00001  2.772589       0    15           3          1.0   143.0
# 2  CusID_00002  4.025352       1    17           1          2.0   168.0
# 3  CusID_00003  3.178054       1    24           0          3.0   165.0
# 4  CusID_00004  3.178054       2    24           3          1.0   147.0
#
#    annual_income  job  is_physically_ok  has_taken_car_loan  \
# 0      10.379753    2                 2                   2
# 1       9.105091    2                 2                   2
# 2      11.934270    2                 2                   0
# 3      11.857515    0                 2                   0
# 4      10.547996    2                 2                   2
#
#    preferable_fuel_choice           vehicle_choice
# 0                       2                    Sedan
# 1                       3  Compact Utility Vehicle
# ...

# %%
dftest.head()
# Out:
#     CustomerID       Age  Gender  City  is_Married  family_size  height  \
# 0  CusID_30000  3.496508       0     5           1          6.0   142.0
# 1  CusID_30001  3.135494       1    15           0          4.0   155.0
# 2  CusID_30002  3.850148       0     1           1          2.0   152.0
# 3  CusID_30003  3.583519       0     8           2          1.0   137.0
# 4  CusID_30004  3.891820       1    18           1          3.0   162.0
#
#    annual_income  job  is_physically_ok  has_taken_car_loan  \
# 0      11.923716    1                 2                   0
# 1      12.025755    1                 2                   0
# 2      11.097425    1                 2                   0
# 3      11.181932    0                 2                   0
# 4       8.779711    1                 2                   2
#
#    preferable_fuel_choice
# 0                       0
# 1                       3
# 2                       3
# 3                       3
# 4                       2

# %%
dftrain.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'City', 'is_Married', 'family_size',
#        'height', 'annual_income', 'job', 'is_physically_ok',
#        'has_taken_car_loan', 'preferable_fuel_choice', 'vehicle_choice'],
#       dtype='object')

# %%
xtrain = dftrain.drop(['CustomerID','vehicle_choice'],axis=1)
ytrain = dftrain['vehicle_choice']

# %%
xtrain.head()
# Out:
#         Age  Gender  City  is_Married  family_size  height  annual_income  \
# 0  3.610918       1    15           0          2.0   160.0      10.379753
# 1  2.772589       0    15           3          1.0   143.0       9.105091
# 2  4.025352       1    17           1          2.0   168.0      11.934270
# 3  3.178054       1    24           0          3.0   165.0      11.857515
# 4  3.178054       2    24           3          1.0   147.0      10.547996
#
#    job  is_physically_ok  has_taken_car_loan  preferable_fuel_choice
# 0    2                 2                   2                       2
# 1    2                 2                   2                       3
# 2    2                 2                   0                       3
# 3    0                 2                   0                       0
# 4    2                 2                   2                       2

# %%
xtrain.shape
# Out:
# (30000, 11)

# %%
ytrain.shape
# Out:
# (30000,)

# %%
dftest.head()
# Out:
#     CustomerID       Age  Gender  City  is_Married  family_size  height  \
# 0  CusID_30000  3.496508       0     5           1          6.0   142.0
# 1  CusID_30001  3.135494       1    15           0          4.0   155.0
# 2  CusID_30002  3.850148       0     1           1          2.0   152.0
# 3  CusID_30003  3.583519       0     8           2          1.0   137.0
# 4  CusID_30004  3.891820       1    18           1          3.0   162.0
#
#    annual_income  job  is_physically_ok  has_taken_car_loan  \
# 0      11.923716    1                 2                   0
# 1      12.025755    1                 2                   0
# 2      11.097425    1                 2                   0
# 3      11.181932    0                 2                   0
# 4       8.779711    1                 2                   2
#
#    preferable_fuel_choice
# 0                       0
# 1                       3
# 2                       3
# 3                       3
# 4                       2

# %%
xtest = dftest.drop('CustomerID',axis=1)

# %%
xtest.head()
# Out:
#         Age  Gender  City  is_Married  family_size  height  annual_income  \
# 0  3.496508       0     5           1          6.0   142.0      11.923716
# 1  3.135494       1    15           0          4.0   155.0      12.025755
# 2  3.850148       0     1           1          2.0   152.0      11.097425
# 3  3.583519       0     8           2          1.0   137.0      11.181932
# 4  3.891820       1    18           1          3.0   162.0       8.779711
#
#    job  is_physically_ok  has_taken_car_loan  preferable_fuel_choice
# 0    1                 2                   0                       0
# 1    1                 2                   0                       3
# 2    1                 2                   0                       3
# 3    0                 2                   0                       3
# 4    1                 2                   2                       2

# %%
xtest.shape
# Out:
# (5000, 11)

# %% [markdown]
# # <font color="#631949" >Modelling</font>

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(xtrain,ytrain)
ypredrf = rf.predict(xtest)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(ytrain, rf.predict(xtrain))
# Out:
# 0.9999333333333333

# %%
round(accuracy_score(ytrain, rf.predict(xtrain))*100,2)
# Out:
# 99.99

# %%
# The Random forest has got a accuracy of 99.99

# %%
accuracy_score(ytrain, dt_model.predict(xtrain))
# Out:
# 0.9999333333333333

# %%
from sklearn.ensemble import GradientBoostingClassifier

gb = GradientBoostingClassifier()
gb.fit(xtrain,ytrain)

ypredgb =gb.predict(xtest)

# %%
accuracy_score(ytrain, gb.predict(xtrain))
# Out:
# 0.8974333333333333

# %%
round(accuracy_score(ytrain, gb.predict(xtrain))*100,2)
# Out:
# 89.74

# %%
#Accuracy score of Gradient boosting classifier is 89.74

# %%
# We got the best accuracy score for Random forest. So Random forest is the best model for our problem

# %%
type(ypredrf)
# Out:
# numpy.ndarray

# %%
submission = pd.DataFrame({
'CustomerID':dftest.CustomerID,
'vehicle_choice':ypredrf
},columns=['CustomerID','vehicle_choice'])

# %%
submission.head()
# Out:
#     CustomerID          vehicle_choice
# 0  CusID_30000  Sports Utility Vehicle
# 1  CusID_30001  Sports Utility Vehicle
# 2  CusID_30002               Crossover
# 3  CusID_30003            Luxury Coupe
# 4  CusID_30004               Hatchback

# %%
submission.shape
# Out:
# (5000, 2)

# %%
submission.to_csv('submission.csv',index=False)
